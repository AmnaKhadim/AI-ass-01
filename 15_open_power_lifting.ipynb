# %%
# !pip install pandas
# !pip install numpy
import pandas as pd
import numpy as np
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.1.4)
# Requirement already satisfied: numpy<2,>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.26.4)

# %%
# Importing CSV file
df = pd.read_csv('/content/openpowerlifting.csv')

data_types = df.dtypes
print(data_types)
# Out:
# MeetID              int64
# Name               object
# Sex                object
# Equipment          object
# Age               float64
# Division           object
# BodyweightKg      float64
# WeightClassKg      object
# Squat4Kg          float64
# BestSquatKg       float64
# Bench4Kg          float64
# BestBenchKg       float64
# Deadlift4Kg       float64
# BestDeadliftKg    float64
# TotalKg           float64
# Place              object
# Wilks             float64
# dtype: object

# %%
duplicates = df.duplicated().sum()
print(f"Number of duplicate rows: {duplicates}")

df.info()
# Out:
# Number of duplicate rows: 266
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148802 entries, 0 to 148801
# Data columns (total 17 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   MeetID          148802 non-null  int64
#  1   Name            148802 non-null  object
#  2   Sex             148802 non-null  object
#  3   Equipment       148802 non-null  object
#  4   Age             39316 non-null   float64
#  5   Division        135162 non-null  object
#  6   BodyweightKg    148426 non-null  float64
#  7   WeightClassKg   148419 non-null  object
#  8   Squat4Kg        614 non-null     float64
#  9   BestSquatKg     108049 non-null  float64
#  10  Bench4Kg        1046 non-null    float64
#  11  BestBenchKg     141035 non-null  float64
#  12  Deadlift4Kg     1248 non-null    float64
#  13  BestDeadliftKg  115504 non-null  float64
#  14  TotalKg         142534 non-null  float64
#  15  Place           148246 non-null  object
#  16  Wilks           142209 non-null  float64
# dtypes: float64(10), int64(1), object(6)
# memory usage: 19.3+ MB

# %%
df.describe()
# Out:
#               MeetID           Age   BodyweightKg    Squat4Kg    BestSquatKg  \
# count  148802.000000  39316.000000  148426.000000  614.000000  108049.000000
# mean     2343.636907     32.661664      87.001177   68.189137     182.068168
# std      1689.239258     13.426411      22.234581  182.962869      68.917057
# min         0.000000      5.000000      17.240000 -425.000000    -285.000000
# 25%      1093.000000     22.500000      71.350000 -110.000000     130.000000
# 50%      1583.000000     29.000000      83.800000  135.000000     180.000000
# 75%      4212.000000     40.500000     100.000000  199.580000     225.000000
# max      5151.000000     95.000000     230.000000  450.000000     560.190000
#
#           Bench4Kg    BestBenchKg  Deadlift4Kg  BestDeadliftKg        TotalKg  \
# count  1046.000000  141035.000000  1248.000000   115504.000000  142534.000000
# mean      1.952275     124.134623    68.384888      201.538912     416.503591
# std     149.313781      52.594498   189.324691       60.802014     212.047276
# min    -360.000000    -362.500000  -402.500000     -275.200000      11.000000
# 25%    -129.375000      82.500000  -140.000000      151.950000     237.500000
# 50%     -34.895000     122.500000   140.000000      205.000000     417.500000
# 75%     142.500000     157.500000   208.650000      245.000000     576.060000
# max     330.000000     455.860000   365.140000      460.400000    1365.310000
#
#                Wilks
# count  142209.000000
# mean      295.880731
# std       129.795112
# min        14.210000
# 25%       198.360000
# 50%       322.190000
# 75%       387.170000
# max       779.380000

# %%
df.head()
# Out:
#    MeetID              Name Sex   Equipment   Age     Division  BodyweightKg  \
# 0       0  Angie Belk Terry   F       Wraps  47.0    Mst 45-49         59.60
# 1       0       Dawn Bogart   F  Single-ply  42.0    Mst 40-44         58.51
# 2       0       Dawn Bogart   F  Single-ply  42.0  Open Senior         58.51
# 3       0       Dawn Bogart   F         Raw  42.0  Open Senior         58.51
# 4       0      Destiny Dula   F         Raw  18.0   Teen 18-19         63.68
#
#   WeightClassKg  Squat4Kg  BestSquatKg  Bench4Kg  BestBenchKg  Deadlift4Kg  \
# 0            60       NaN        47.63       NaN        20.41          NaN
# 1            60       NaN       142.88       NaN        95.25          NaN
# 2            60       NaN       142.88       NaN        95.25          NaN
# 3            60       NaN          NaN       NaN        95.25          NaN
# 4          67.5       NaN          NaN       NaN        31.75          NaN
#
#    BestDeadliftKg  TotalKg Place   Wilks
# 0           70.31   138.35     1  155.05
# 1          163.29   401.42     1  456.38
# 2          163.29   401.42     1  456.38
# 3             NaN    95.25     1  108.29
# 4           90.72   122.47     1  130.47
